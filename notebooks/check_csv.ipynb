# %% [markdown]
# # Imports

# %%
import pandas as pd
import json

# %%
reader = csv.reader(open(path,  encoding="ISO-8859-1"), delimiter=';')
# for row in reader:
#     print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 reader = csv.reader(open(path,  encoding="ISO-8859-1"), delimiter=';')
#
# NameError: name 'path' is not defined

# %% [markdown]
# # CSV

# %%
path = '../raw_data/test_file.csv'
# json.load(open("../app/config.json"))
# Out:
# {'010.000 (Mieteingang EG)': '010.000',
#  '010.001 (Mieteingang 1OG)': '010.001',
#  '010.002 (Mieteingang 2OG)': '010.002',
#  '010.003 (Mieteingang 3OG)': '010.003',
#  '010.004 (Mieteingang 4OG)': '010.004',
#  '020.000 (Betriebskostenvorauszahlungen)': '020.000',
#  '020.001 (Betriebskostenvorauszahlungen)': '020.001',
#  '020.002 (Betriebskostenvorauszahlungen)': '020.002',
#  '020.003 (Betriebskostenvorauszahlungen)': '020.003',
#  '020.004 (Betriebskostenvorauszahlungen)': '020.004',
#  '030.000 (Betriebskosten unaufgeschlüsselt)': '030.000',
#  '030.010 (Gas)': '030.010',
#  '030.020 (Strom)': '030.020',
#  '030.021 (Wasser)': '030.021',
#  '030.022 (Abwasser)': '030.022',
#  '030.030 (Müll)': '030.030',
#  '030.031 (Niederschlagswasser)': '030.031',
#  '030.060 (Internet)': '030.060',
#  '040.000 (Instandhaltungskosten)': '040.000',
#  '040.001 (Beraterkosten)': '040.001',
#  '040.002 (Sonst. Anschaffungskosten)': '040.002',
#  '050.000 (Versicherungen)': '050.000',
#  '060.000 (Abschreibungen)': '060.000',
#  '070.000 (Zinsen)': '070.000',
#  '080.000 (Kaufpreis)': '080.000',
#  '080.010 (Kaufpreisnebenkosten)': '080.010'}

# %%
df.astype('string')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Buchungstag               244 non-null    string
#  1   Valuta                    242 non-null    string
#  2   Textschlüssel             242 non-null    string
#  3   Primanota                 242 non-null    string
#  4   Zahlungsempfänger         232 non-null    string
#  5   ZahlungsempfängerKto      242 non-null    string
#  6   ZahlungsempfängerIBAN     229 non-null    string
#  7   ZahlungsempfängerBLZ      229 non-null    string
#  8   ZahlungsempfängerBIC      229 non-null    string
#  9   Vorgang/Verwendungszweck  242 non-null    string
#  10  Kundenreferenz            111 non-null    string
#  11  Währung                   244 non-null    string
#  12  Umsatz                    244 non-null    string
#  13  Soll/Haben                244 non-null    string
# dtypes: string(14)
# memory usage: 26.9 KB

# %%
date_columns = ['Buchungstag', 'Valuta']
df = pd.read_csv(path, 
                 sep=';', 
                 skiprows=15, 
                 encoding="ISO-8859-1", 
                 decimal=',', 
                 thousands='.',
                 parse_dates=date_columns, 
                 dayfirst=True,
                )
df['Umsatz'] = df.Umsatz.astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Buchungstag               244 non-null    datetime64[ns]
#  1   Valuta                    242 non-null    datetime64[ns]
#  2   Textschlüssel             242 non-null    object
#  3   Primanota                 242 non-null    float64
#  4   Zahlungsempfänger         232 non-null    object
#  5   ZahlungsempfängerKto      242 non-null    float64
#  6   ZahlungsempfängerIBAN     229 non-null    object
#  7   ZahlungsempfängerBLZ      229 non-null    float64
#  8   ZahlungsempfängerBIC      229 non-null    object
#  9   Vorgang/Verwendungszweck  242 non-null    object
#  10  Kundenreferenz            111 non-null    object
#  11  Währung                   244 non-null    object
#  12  Umsatz                    244 non-null    float64
#  13  Soll/Haben                244 non-null    object
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 26.9+ KB

# %%
df.head()
# Out:
#   Buchungstag     Valuta           Textschlüssel  Primanota  \
# 0  2022-01-14 2022-01-14  05 Auszahlung girocard      931.0
# 1  2022-01-14 2022-01-14     05 Basislastschrift      931.0
# 2  2022-01-14 2022-01-14     05 Basislastschrift      931.0
# 3  2022-01-14 2022-01-14         08 Dauerauftrag      900.0
# 4  2022-01-05 2022-01-05     05 Basislastschrift      931.0
#
#                Zahlungsempfänger  ZahlungsempfängerKto  \
# 0  Sparda-Bank Baden-W rttemberg                   0.0
# 1           IKEA Deutschland Gmb                   0.0
# 2                   HORNBACH ULM                   0.0
# 3               SWU Energie GmbH                   0.0
# 4                   HORNBACH ULM                   0.0
#
#     ZahlungsempfängerIBAN  ZahlungsempfängerBLZ ZahlungsempfängerBIC  \
# 0  DE84600908001299140080            60090800.0          GENODEF1S02
# 1  DE81302201900029610169            30220190.0          HYVEDEMM414
# 2  DE35500400000600247159            50040000.0          COBADEFFXXX
# 3  DE53630500000000100089            63050000.0          SOLADES1ULM
# 4  DE35500400000600247159            50040000.0          COBADEFFXXX
#
#                             Vorgang/Verwendungszweck  \
# 0  Lastschrift-Kartenzahlung Sparda-Bank Baden-Wu...
# 1  Lastschrift 120110050050660221200003280 ELV654...
# 2  Lastschrift 120109390056578221200006310 ELV651...
# 3  Überweisung Vertrtagskontonr.: 9204428961 /*DA...
# 4  Lastschrift 030116050055508221200006316 ELV651...
#
#                         Kundenreferenz Währung  Umsatz Soll/Haben
# 0           00074840056633140122083727     EUR   80.00          S
# 1  12011005005066022120000328065450116     EUR  264.00          S
# 2  12010939005657822120000631065148356     EUR  119.10          S
# 3                                  NaN     EUR   85.00          S
# 4  03011605005550822120000631665148356     EUR   20.75          S

# %%
df
# Out:
#     Buchungstag      Valuta            Textschlüssel  Primanota  \
# 0    14.01.2022  14.01.2022   05 Auszahlung girocard      931.0
# 1    14.01.2022  14.01.2022      05 Basislastschrift      931.0
# 2    14.01.2022  14.01.2022      05 Basislastschrift      931.0
# 3    14.01.2022  14.01.2022          08 Dauerauftrag      900.0
# 4    05.01.2022  05.01.2022      05 Basislastschrift      931.0
# ..          ...         ...                      ...        ...
# 240  01.03.2021  01.03.2021  51 Überweisungsgutschr.      931.0
# 241  01.03.2021  01.03.2021      16 Euro-Überweisung      801.0
# 242         NaN         NaN                      NaN        NaN
# 243  01.03.2021         NaN                      NaN        NaN
# 244  14.01.2022         NaN                      NaN        NaN
#
#                  Zahlungsempfänger  ZahlungsempfängerKto  \
# 0    Sparda-Bank Baden-W rttemberg                   0.0
# 1             IKEA Deutschland Gmb                   0.0
# 2                     HORNBACH ULM                   0.0
# 3                 SWU Energie GmbH                   0.0
# 4                     HORNBACH ULM                   0.0
# ..                             ...                   ...
# 240                MOHAMMAD ALHMAD                   0.0
# 241                 Hartschuh GmbH             2528002.0
# 242                            NaN                   NaN
# 243                            NaN                   NaN
# 244                            NaN                   NaN
#
#       ZahlungsempfängerIBAN  ZahlungsempfängerBLZ ZahlungsempfängerBIC  \
# 0    DE84600908001299140080            60090800.0          GENODEF1S02
# 1    DE81302201900029610169            30220190.0          HYVEDEMM414
# 2    DE35500400000600247159            50040000.0          COBADEFFXXX
# 3    DE53630500000000100089            63050000.0          SOLADES1ULM
# 4    DE35500400000600247159            50040000.0          COBADEFFXXX
# ..                      ...                   ...                  ...
# 240  DE39630500001011336690            63050000.0          SOLADES1ULM
# 241  DE76630901000002528002            63090100.0          ULMVDE66XXX
# 242                     NaN                   NaN                  NaN
# 243                     NaN                   NaN                  NaN
# 244                     NaN                   NaN                  NaN
#
#                               Vorgang/Verwendungszweck  \
# 0    Lastschrift-Kartenzahlung Sparda-Bank Baden-Wu...
# 1    Lastschrift 120110050050660221200003280 ELV654...
# 2    Lastschrift 120109390056578221200006310 ELV651...
# 3    Überweisung Vertrtagskontonr.: 9204428961 /*DA...
# 4    Lastschrift 030116050055508221200006316 ELV651...
# ..                                                 ...
# 240                                  Überweisung miete
# 241  Überweisung Rechnungsnr.: 403117 Kundennr.: 50...
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
#                           Kundenreferenz Währung     Umsatz Soll/Haben
# 0             00074840056633140122083727     EUR      80,00          S
# 1    12011005005066022120000328065450116     EUR     264,00          S
# 2    12010939005657822120000631065148356     EUR     119,10          S
# 3                                    NaN     EUR      85,00          S
# 4    03011605005550822120000631665148356     EUR      20,75          S
# ..                                   ...     ...        ...        ...
# 240                                  NaN     EUR     400,00          H
# 241                                  NaN     EUR     401,89          S
# 242                                  NaN     NaN        NaN        NaN
# 243                         Anfangssaldo     EUR  23.953,83          H
# 244                             Endsaldo     EUR  11.066,59          H
#
# [245 rows x 14 columns]

# %%
for c, row in df.iterrows():
    print(row.Umsatz)
# Out:
# 80.0
# 264.0
# 119.1
# 85.0
# 20.75
# 12.99
# 1010.0
# 760.0
# 1346.0
# 59.85
# 82.43
# 1045.0
# 349.99
# 52.0
# 50.78
# 1557.47
# 3.9
